# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
acc  = [0.340, 0.647, 0.672, 0.856, 0.892, 0.904, 0.929, 0.927, 0.877, 0.944, 0.953, 0.967, 0.962, 0.883, 0.966]
val_loss = [0.971, 0.875, 0.982, 0.99, 0.993, 0.874, 0.853, 0.938, 0.948, 0.983, 1.0, 0.922, 1.01, 0.931, 0.976]
train_loss = [0.974, 1.0, 1.01, 1.05, 0.946, 0.874, 0.941, 1.0, 0.984, 0.999, 0.973, 1.01, 0.917, 0.974, 0.926]

# %%
df = pd.DataFrame()
df['Accuracy'] = acc 
df['Validation Loss'] = val_loss 
df['Training Loss'] = train_loss
df['Epoch'] = range(15)

df[['Accuracy', 'Training Loss', 'Validation Loss']] = df[['Accuracy', 'Training Loss', 'Validation Loss']].astype(float)

# %%
df
# Out:
#     Accuracy  Validation Loss  Training Loss  Epoch
# 0      0.340            0.971          0.974      0
# 1      0.647            0.875          1.000      1
# 2      0.672            0.982          1.010      2
# 3      0.856            0.990          1.050      3
# 4      0.892            0.993          0.946      4
# 5      0.904            0.874          0.874      5
# 6      0.929            0.853          0.941      6
# 7      0.927            0.938          1.000      7
# 8      0.877            0.948          0.984      8
# 9      0.944            0.983          0.999      9
# 10     0.953            1.000          0.973     10
# 11     0.967            0.922          1.010     11
# 12     0.962            1.010          0.917     12
# 13     0.883            0.931          0.974     13
# 14     0.966            0.976          0.926     14

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Accuracy         15 non-null     float64
#  1   Validation Loss  15 non-null     float64
#  2   Training Loss    15 non-null     float64
#  3   Epoch            15 non-null     int64
# dtypes: float64(3), int64(1)
# memory usage: 608.0 bytes

# %%
sns.lineplot(data=df, x='Epoch', y='Training Loss', marker='o').set(title="Training Loss")
# Out:
# [Text(0.5, 1.0, 'Training Loss')]

# %%
sns.lineplot(data=df, x='Epoch', y='Validation Loss', marker='o').set(title="Validation Loss")
# Out:
# [Text(0.5, 1.0, 'Validation Loss')]

# %%
sns.lineplot(data=df, x='Epoch', y='Accuracy', marker='o').set(title="Validation Accuracy")
# Out:
# [Text(0.5, 1.0, 'Validation Accuracy')]

# %%
sns.lineplot(data=df, x='Epoch', y='Accuracy', marker='o').set(title="Validation Accuracy")

# %%
losses = [0.971, 0.875, 0.982, 0.99, 0.993, 0.874, 0.853, 0.938, 0.948, 0.983, 1.0, 0.922, 1.01, 0.931, 0.976]+[0.974, 1.0, 1.01, 1.05, 0.946, 0.874, 0.941, 1.0, 0.984, 0.999, 0.973, 1.01, 0.917, 0.974, 0.926]
phase = ['validation',]*15 + ['train',]*15
epoch = list(range(1, 16)) + list(range(1, 16))

# %%
df1 = pd.DataFrame()
df1['Loss'] = losses
df1['Phase'] = phase
df1['epoch'] = epoch

# %%
df1
# Out:
#      Loss       Phase  epoch
# 0   0.971  validation      1
# 1   0.875  validation      2
# 2   0.982  validation      3
# 3   0.990  validation      4
# 4   0.993  validation      5
# 5   0.874  validation      6
# 6   0.853  validation      7
# 7   0.938  validation      8
# 8   0.948  validation      9
# 9   0.983  validation     10
# 10  1.000  validation     11
# 11  0.922  validation     12
# 12  1.010  validation     13
# 13  0.931  validation     14
# 14  0.976  validation     15
# 15  0.974       train      1
# 16  1.000       train      2
# 17  1.010       train      3
# 18  1.050       train      4
# 19  0.946       train      5
# 20  0.874       train      6
# 21  0.941       train      7
# 22  1.000       train      8
# 23  0.984       train      9
# 24  0.999       train     10
# 25  0.973       train     11
# 26  1.010       train     12
# 27  0.917       train     13
# 28  0.974       train     14
# 29  0.926       train     15

# %%
sns.lineplot(data=df1, x='epoch', y='Loss', hue='Phase', marker='o').set(title="Losses")
# Out:
# [Text(0.5, 1.0, 'Losses')]
